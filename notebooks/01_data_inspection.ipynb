# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Starting Data Inspection

# %% [markdown]
# ## Load first dataset

# %%
covid_df = pd.read_csv("../data/raw/WHO-COVID-19-global-daily-data.csv")
covid_df.head()
# Out:
#   Date_reported Country_code         Country WHO_region  New_cases  \
# 0    2020-01-04           AF     Afghanistan        EMR        NaN
# 1    2020-01-04           DZ         Algeria        AFR        NaN
# 2    2020-01-04           AL         Albania        EUR        NaN
# 3    2020-01-04           AI        Anguilla        AMR        NaN
# 4    2020-01-04           AS  American Samoa        WPR        0.0
#
#    Cumulative_cases  New_deaths  Cumulative_deaths
# 0                 0         NaN                  0
# 1                 0         NaN                  0
# 2                 0         NaN                  0
# 3                 0         NaN                  0
# 4                 0         0.0                  0

# %%
covid_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 538080 entries, 0 to 538079
# Data columns (total 8 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Date_reported      538080 non-null  object
#  1   Country_code       535838 non-null  object
#  2   Country            538080 non-null  object
#  3   WHO_region         538080 non-null  object
#  4   New_cases          213004 non-null  float64
#  5   Cumulative_cases   538080 non-null  int64
#  6   New_deaths         155252 non-null  float64
#  7   Cumulative_deaths  538080 non-null  int64
# dtypes: float64(2), int64(2), object(4)
# memory usage: 32.8+ MB

# %%
covid_df.describe(include="all").T
# Out:
#                       count unique          top    freq            mean  \
# Date_reported        538080   2242   2026-02-22     240             NaN
# Country_code         535838    239           AF    2242             NaN
# Country              538080    240  Afghanistan    2242             NaN
# WHO_region           538080      7          EUR  139004             NaN
# New_cases          213004.0    NaN          NaN     NaN     3657.893429
# Cumulative_cases   538080.0    NaN          NaN     NaN  2153323.828743
# New_deaths         155252.0    NaN          NaN     NaN       45.811661
# Cumulative_deaths  538080.0    NaN          NaN     NaN    22394.376563
#
#                              std      min     25%      50%       75%  \
# Date_reported                NaN      NaN     NaN      NaN       NaN
# Country_code                 NaN      NaN     NaN      NaN       NaN
# Country                      NaN      NaN     NaN      NaN       NaN
# ...

# %%
covid_df.isnull().sum()/len(covid_df)
# Out:
# Date_reported        0.000000
# Country_code         0.004167
# Country              0.000000
# WHO_region           0.000000
# New_cases            0.604141
# Cumulative_cases     0.000000
# New_deaths           0.711470
# Cumulative_deaths    0.000000
# dtype: float64

# %% [markdown]
# In a initial inspection we can see that some features like 'New_cases' or 'New_deaths' appear to have a lot of null values (~60% and ~71% respectively). Nevertheless, these are possibly Missing Not At Random (MNAR) data, since there probably were no new cases or deaths for that particular date. Further inspection needed to confirm

# %%
covid_df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Load second dataset

# %%
vaccines = pd.read_csv("../data/raw/COV_VAC_UPTAKE_2021_2023.csv")
vaccines.head()
# Out:
#   COUNTRY  COVID_VACCINE_ADM_TOT_A1D  COVID_VACCINE_ADM_TOT_BOOST  \
# 0     BTN                   187866.0                          NaN
# 1     BTN                   480836.0                          NaN
# 2     BTN                   483092.0                          NaN
# 3     BTN                   484797.0                          NaN
# 4     BTN                   530103.0                          NaN
#
#    COVID_VACCINE_ADM_TOT_CPS  COVID_VACCINE_ADM_TOT_DOSES  \
# 0                        NaN                     187866.0
# 1                        NaN                     480836.0
# 2                        NaN                     483092.0
# 3                      490.0                     485619.0
# 4                   470465.0                    1000568.0
#
#    COVID_VACCINE_ADM_TOT_DOSES_PER100  COVID_VACCINE_COV_TOT_A1D  \
# 0                                24.0                       24.0
# 1                                62.0                       62.0
# ...

# %%
vaccines.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7608 entries, 0 to 7607
# Data columns (total 12 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   COUNTRY                             7608 non-null   object
#  1   COVID_VACCINE_ADM_TOT_A1D           7329 non-null   float64
#  2   COVID_VACCINE_ADM_TOT_BOOST         4830 non-null   float64
#  3   COVID_VACCINE_ADM_TOT_CPS           7101 non-null   float64
#  4   COVID_VACCINE_ADM_TOT_DOSES         7426 non-null   float64
#  5   COVID_VACCINE_ADM_TOT_DOSES_PER100  7199 non-null   float64
#  6   COVID_VACCINE_COV_TOT_A1D           7112 non-null   float64
#  7   COVID_VACCINE_COV_TOT_BOOST         4403 non-null   float64
#  8   COVID_VACCINE_COV_TOT_CPS           6803 non-null   float64
#  9   COVID_VACCINE_DATE_INTRO_FIRST      6807 non-null   object
#  10  COVID_VACCINE_DATE_REPORT_TOT_LAST  7375 non-null   object
# ...

# %%
vaccines.describe().T
# Out:
#                                      count          mean           std   min  \
# COVID_VACCINE_ADM_TOT_A1D           7329.0  2.111683e+07  1.049170e+08  11.0
# COVID_VACCINE_ADM_TOT_BOOST         4830.0  1.092436e+07  5.811423e+07   1.0
# COVID_VACCINE_ADM_TOT_CPS           7101.0  1.900064e+07  9.849577e+07   2.0
# COVID_VACCINE_ADM_TOT_DOSES         7426.0  4.757045e+07  2.480843e+08  20.0
# COVID_VACCINE_ADM_TOT_DOSES_PER100  7199.0  1.179469e+02  8.402130e+01   1.0
# COVID_VACCINE_COV_TOT_A1D           7112.0  5.224297e+01  2.841871e+01   1.0
# COVID_VACCINE_COV_TOT_BOOST         4403.0  3.009970e+01  2.295098e+01   1.0
# COVID_VACCINE_COV_TOT_CPS           6803.0  4.845024e+01  2.771003e+01   1.0
#
#                                          25%        50%         75%  \
# COVID_VACCINE_ADM_TOT_A1D           191660.0  1951054.0   7978710.0
# COVID_VACCINE_ADM_TOT_BOOST          43079.0   575651.0   4364627.5
# COVID_VACCINE_ADM_TOT_CPS           163032.0  1427883.0   6887907.0
# ...

# %%
vaccines.isnull().sum()/len(vaccines)
# Out:
# COUNTRY                               0.000000
# COVID_VACCINE_ADM_TOT_A1D             0.036672
# COVID_VACCINE_ADM_TOT_BOOST           0.365142
# COVID_VACCINE_ADM_TOT_CPS             0.066640
# COVID_VACCINE_ADM_TOT_DOSES           0.023922
# COVID_VACCINE_ADM_TOT_DOSES_PER100    0.053759
# COVID_VACCINE_COV_TOT_A1D             0.065195
# COVID_VACCINE_COV_TOT_BOOST           0.421267
# COVID_VACCINE_COV_TOT_CPS             0.105810
# COVID_VACCINE_DATE_INTRO_FIRST        0.105284
# COVID_VACCINE_DATE_REPORT_TOT_LAST    0.030626
# DATE                                  0.000000
# dtype: float64

# %%
covid_df.shape
# Out:
# (538080, 8)

# %%
first_entry = covid_df["Date_reported"].min()
last_entry = covid_df["Date_reported"].max()
print(f"The first data entry in this dataset is from: {first_entry} and the last one from: {last_entry}")
# Out:
# The first data entry in this dataset is from: 2020-01-04 and the last one from: 2026-02-22

# %%
vaccines.shape
# Out:
# (7608, 12)

# %%
first_entry_vacc = vaccines["DATE"].min()
last_entry_vacc = vaccines["DATE"].max()
print(f"The first data entry in this dataset is from: {first_entry_vacc} and the last one from: {last_entry_vacc}")
# Out:
# The first data entry in this dataset is from: 2021-01-31 and the last one from: 2023-12-31

# %%
first_date = covid_df["Date_reported"] >= '2021-01-31'
second_date = covid_df["Date_reported"] <= '2023-12-31'

# %%
new_covid = covid_df[second_date & first_date]
new_covid.head()
# Out:
#       Date_reported Country_code                       Country WHO_region  \
# 94320    2021-01-31           ZW                      Zimbabwe        AFR
# 94321    2021-01-31           US      United States of America        AMR
# 94322    2021-01-31           ZM                        Zambia        AFR
# 94323    2021-01-31           VI  United States Virgin Islands        AMR
# 94324    2021-01-31           YE                         Yemen        EMR
#
#        New_cases  Cumulative_cases  New_deaths  Cumulative_deaths
# 94320      319.0             33271        15.0               1193
# 94321   164238.0          25863033      3266.0             452123
# 94322     1728.0             53352        17.0                745
# 94323        NaN              2398         NaN                 24
# 94324        NaN              2124         NaN                616

# %%
new_covid.shape
# Out:
# (255600, 8)

# %%
new_first = new_covid["Date_reported"].min()
new_last = new_covid["Date_reported"].max()
print(f"The first data entry in this dataset is from: {new_first} and the last one from: {new_last}")
# Out:
# The first data entry in this dataset is from: 2021-01-31 and the last one from: 2023-12-31
